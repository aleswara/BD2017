# %%
import pandas as pd
import numpy as np
#from pandas_profiling import ProfileReport
from googlemaps import Client as GoogleMaps
import googlemaps
import gmaps
#from keplergl import KeplerGl
import geopandas as gpd
import warnings
warnings.simplefilter("ignore")

# %%
# Load and explore the data
addresses = pd.read_excel('Dealer-coordinates-running.xlsx')#Dealer-coordinates-running
# Look at the top few rows
#addresses.head()
# Understand data types
#addresses.describe()

# %%
# Create a new column called Full Address
addresses['Full_Address'] = addresses['Name'].astype(str) + ',' + \
                addresses['Street'] + ',' + \
                addresses['City']
                
#addresses.head()

# %%
# This is where we will need the API key
gmaps = googlemaps.Client(key='AIzaSyDwPrSmSXgtB_EWezvzxtU5Z5omC6De3gA')

# %%
# Lets just pass the full address column to the google API
coordinates= addresses.iloc[:,-1:]
coordinates.tail()
# Out:
#                                           Full_Address
# 453           Gätzi Sport AG ,St. Gallerstr. 94,Gossau
# 454  Bavaria Motorcycles ,Fichtheimer Feld 7,Landau...
# 455  BikeLaden GmbH ,Romanshornerstrasse 52,Kreuzli...
# 456   2Rad Lampenscherf GmbH ,Wehrstrasse 44990,Hilden
# 457  Love-ebikes ,684 Dumbarton Road 684,Glasgow Sc...

# %%
results = []
for i in range(len(coordinates)):
    geocode_result = gmaps.geocode(coordinates['Full_Address'][i])
    results.append(geocode_result)

# %%
#results

# %%
# Initialize latitude and longitude columns with NaN values
coordinates['latitude'] = np.nan
coordinates['longitude'] = np.nan

# %%
for j in range(len(results)):
    temp_result = results[j]
    if(len(temp_result)>0):
        print('lat', temp_result[0]['geometry']['location']['lat'])
        print('lng', temp_result[0]['geometry']['location']['lng'])
# Out:
# lat 53.4635644
# lng 9.7973225
# lat 51.3772701
# lng 12.4365885
# lat 48.00334
# lng 13.65613
# lat 48.13337689999999
# lng 15.1413592
# lat 48.1044141
# lng 14.826109
# lat 48.4630623
# lng 14.0905073
# lat 48.07827349999999
# lng 14.3761515
# lat 47.7467944
# lng 13.0846523
# lat 47.5557624
# lng 12.1547743
# lat 47.972712
# lng 16.2147282
# lat 47.9485474
# lng 14.8958248
# lat 48.3304669
# lng 16.0515005
# lat 48.40055779999999
# lng 15.5777201
# lat 48.32064
# lng 14.289322
# lat 48.3400727
# lng 14.1686677
# lat 48.5671791
# lng 13.9815834
# lat 48.5013119
# lng 14.500796
# lat 48.05009
# lng 14.41827
# lat 47.6434647
# lng 12.7150376
# lat 47.8022533
# lng 13.0674869
# lat 47.2773954
# lng 11.4881023
# lat 47.1504364
# lng 9.8109094
# lat 47.8528203
# lng 16.8386332
# lat 47.3703979
# lng 16.1225355
# lat 47.1297632
# lng 15.3179421
# lat 46.7965319
# lng 13.490541
# lat 47.5008936
# lng 9.7369503
# lat 48.001925
# lng 13.6129627
# lat 47.3835567
# lng 13.6695091
# ...

# %%
for k in range(len(results)):
    temp_result = results[k]
    if(len(temp_result)>0):
        coordinates['latitude'][k] = temp_result[0]['geometry']['location']['lat']
        coordinates['longitude'][k] = temp_result[0]['geometry']['location']['lng']

# %%
coordinates['latitude']
# Out:
# 0      53.463564
# 1      51.377270
# 2      48.003340
# 3      48.133377
# 4      48.104414
#          ...
# 453    47.416554
# 454    48.650673
# 455    47.641127
# 456    51.166739
# 457    55.870881
# Name: latitude, Length: 458, dtype: float64

# %%
coordinates['longitude']
# Out:
# 0       9.797322
# 1      12.436588
# 2      13.656130
# 3      15.141359
# 4      14.826109
#          ...
# 453     9.254117
# 454    12.706083
# 455     9.190789
# 456     6.926537
# 457    -4.320349
# Name: longitude, Length: 458, dtype: float64

# %%
# Lets join the results with original file
addresses['Latitude']=coordinates['latitude']
addresses['Longitude']= coordinates['longitude']
addresses.head()
# Out:
#   additional check needed?                                               Name  \
# 0                      yes                      Hauschild Der Zweirad Experte
# 1                      yes               Martin Götze "Schöne schnelle Räder"
# 2                      YES  Lagerhaus Vöcklabruck - Gmunden eGen Filiale A...
# 3                       no                   Weichberger Gesellschaft m.b.H.
# 4                       no                   Weichberger Gesellschaft m.b.H.
#
#                 Street Postalcode               City  \
# 0       Hauptstraße 44      21629      Neu Wulmstorf
# 1    Rostocker Str. 40       4349            Leipzig
# 2  VöcklabruKalkofen 1       4644           Mühldorf
# 3        Wiener Str. 6       3250  Wieselburg/Erlauf
# 4         Dieselstr. 9       3362          Amstetten
#
#                       email email ending (contry indicator)   \
# 0                       NaN                              NaN
# ...

# %%
addresses.to_excel("Dealer-Coordinates-List.xlsx", index = False)
